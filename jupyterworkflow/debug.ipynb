# %%
# %matplotlib inline
from jupyterworkflow.data import load_data
data = load_data()
pivoted = data.pivot_table('Fremont Bridge Total', index=data.index.time, columns=data.index.date)
pivoted.plot(legend=False, alpha=0.01);

# %% [markdown]
# The graph is different from earlier, why?

# %%
pivoted.index
# Out:
# Index([01:00:00, 02:00:00, 03:00:00, 04:00:00, 05:00:00, 06:00:00, 07:00:00,
#        08:00:00, 09:00:00, 10:00:00, 11:00:00, 12:00:00],
#       dtype='object')

# %% [markdown]
# Coz the time is 12hrs rather than 24 hrs

# %%
import numpy as np
np.unique(data.index.time)
# Out:
# array([datetime.time(1, 0), datetime.time(2, 0), datetime.time(3, 0),
#        datetime.time(4, 0), datetime.time(5, 0), datetime.time(6, 0),
#        datetime.time(7, 0), datetime.time(8, 0), datetime.time(9, 0),
#        datetime.time(10, 0), datetime.time(11, 0), datetime.time(12, 0)],
#       dtype=object)

# %%
data.head(24)
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 12:00:00                  12.0                           7.0
# 2019-11-01 01:00:00                   7.0                           0.0
# 2019-11-01 02:00:00                   1.0                           0.0
# 2019-11-01 03:00:00                   6.0                           6.0
# 2019-11-01 04:00:00                   6.0                           5.0
# 2019-11-01 05:00:00                  20.0                           9.0
# 2019-11-01 06:00:00                  97.0                          43.0
# 2019-11-01 07:00:00                 299.0                         120.0
# 2019-11-01 08:00:00                 583.0                         261.0
# 2019-11-01 09:00:00                 332.0                         130.0
# 2019-11-01 10:00:00                 124.0                          56.0
# 2019-11-01 11:00:00                  94.0                          46.0
# ...

# %% [markdown]
# ______ After Changing the time formath from %H to %I ________

# %%
# %matplotlib inline
from jupyterworkflow.data import load_data
data = load_data()
pivoted = data.pivot_table('Fremont Bridge Total', index=data.index.time, columns=data.index.date)
pivoted.plot(legend=False, alpha=0.01);

# %%
import numpy as np
np.unique(data.index.time)
# Out:
# array([datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0),
#        datetime.time(3, 0), datetime.time(4, 0), datetime.time(5, 0),
#        datetime.time(6, 0), datetime.time(7, 0), datetime.time(8, 0),
#        datetime.time(9, 0), datetime.time(10, 0), datetime.time(11, 0),
#        datetime.time(12, 0), datetime.time(13, 0), datetime.time(14, 0),
#        datetime.time(15, 0), datetime.time(16, 0), datetime.time(17, 0),
#        datetime.time(18, 0), datetime.time(19, 0), datetime.time(20, 0),
#        datetime.time(21, 0), datetime.time(22, 0), datetime.time(23, 0)],
#       dtype=object)
